# %%
pip install chromadb openai langchain fastapi uvicorn sentence-transformers
# Out:
# Requirement already satisfied: chromadb in ./AIML_POC/lib/python3.10/site-packages (0.6.3)
# Requirement already satisfied: openai in ./AIML_POC/lib/python3.10/site-packages (1.61.0)
# Requirement already satisfied: langchain in ./AIML_POC/lib/python3.10/site-packages (0.3.17)
# Requirement already satisfied: fastapi in ./AIML_POC/lib/python3.10/site-packages (0.115.7)
# Requirement already satisfied: uvicorn in ./AIML_POC/lib/python3.10/site-packages (0.34.0)
# Requirement already satisfied: sentence-transformers in ./AIML_POC/lib/python3.10/site-packages (3.4.1)
# Requirement already satisfied: typer>=0.9.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: mmh3>=4.0.1 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: tqdm>=4.65.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: grpcio>=1.58.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (1.70.0)
# Requirement already satisfied: overrides>=7.3.1 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: pypika>=0.48.9 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: build>=1.0.3 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (2.10.6)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: tenacity>=8.2.3 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (0.50b0)
# Requirement already satisfied: kubernetes>=28.1.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (32.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: httpx>=0.27.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: tokenizers>=0.13.2 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: importlib-resources in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: posthog>=2.4.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (3.11.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: rich>=10.11.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: orjson>=3.9.12 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: PyYAML>=6.0.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: numpy>=1.22.5 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./AIML_POC/lib/python3.10/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./AIML_POC/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: sniffio in ./AIML_POC/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./AIML_POC/lib/python3.10/site-packages (from openai) (4.8.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./AIML_POC/lib/python3.10/site-packages (from openai) (0.8.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in ./AIML_POC/lib/python3.10/site-packages (from langchain) (0.3.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./AIML_POC/lib/python3.10/site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in ./AIML_POC/lib/python3.10/site-packages (from langchain) (0.3.33)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./AIML_POC/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: requests<3,>=2 in ./AIML_POC/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./AIML_POC/lib/python3.10/site-packages (from langchain) (2.0.37)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in ./AIML_POC/lib/python3.10/site-packages (from langchain) (0.3.4)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in ./AIML_POC/lib/python3.10/site-packages (from fastapi) (0.45.3)
# Requirement already satisfied: click>=7.0 in ./AIML_POC/lib/python3.10/site-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in ./AIML_POC/lib/python3.10/site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in ./AIML_POC/lib/python3.10/site-packages (from sentence-transformers) (4.48.2)
# Requirement already satisfied: torch>=1.11.0 in ./AIML_POC/lib/python3.10/site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in ./AIML_POC/lib/python3.10/site-packages (from sentence-transformers) (0.28.0)
# Requirement already satisfied: scikit-learn in ./AIML_POC/lib/python3.10/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: Pillow in ./AIML_POC/lib/python3.10/site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: scipy in ./AIML_POC/lib/python3.10/site-packages (from sentence-transformers) (1.15.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./AIML_POC/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./AIML_POC/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./AIML_POC/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: propcache>=0.2.0 in ./AIML_POC/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./AIML_POC/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: attrs>=17.3.0 in ./AIML_POC/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./AIML_POC/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./AIML_POC/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in ./AIML_POC/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: pyproject_hooks in ./AIML_POC/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in ./AIML_POC/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: packaging>=19.1 in ./AIML_POC/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: certifi in ./AIML_POC/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in ./AIML_POC/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: filelock in ./AIML_POC/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./AIML_POC/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.9.0)
# Requirement already satisfied: six>=1.9.0 in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: requests-oauthlib in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3>=1.24.2 in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in ./AIML_POC/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./AIML_POC/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (1.33)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./AIML_POC/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./AIML_POC/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: coloredlogs in ./AIML_POC/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in ./AIML_POC/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.1.24)
# Requirement already satisfied: protobuf in ./AIML_POC/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in ./AIML_POC/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in ./AIML_POC/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in ./AIML_POC/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./AIML_POC/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pydantic-core==2.27.2 in ./AIML_POC/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./AIML_POC/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./AIML_POC/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./AIML_POC/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./AIML_POC/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in ./AIML_POC/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: jinja2 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: triton==3.2.0 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: networkx in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./AIML_POC/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./AIML_POC/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in ./AIML_POC/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: regex!=2019.12.17 in ./AIML_POC/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: shellingham>=1.3.0 in ./AIML_POC/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in ./AIML_POC/lib/python3.10/site-packages (from uvicorn) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in ./AIML_POC/lib/python3.10/site-packages (from uvicorn) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in ./AIML_POC/lib/python3.10/site-packages (from uvicorn) (1.0.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./AIML_POC/lib/python3.10/site-packages (from uvicorn) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in ./AIML_POC/lib/python3.10/site-packages (from uvicorn) (14.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./AIML_POC/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in ./AIML_POC/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./AIML_POC/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./AIML_POC/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./AIML_POC/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.1)
# Requirement already satisfied: zipp>=3.20 in ./AIML_POC/lib/python3.10/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./AIML_POC/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./AIML_POC/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in ./AIML_POC/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./AIML_POC/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./AIML_POC/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import hashlib
import chromadb
from sentence_transformers import SentenceTransformer

# Load a transformer model for embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Initialize ChromaDB with Persistent Storage
client = chromadb.PersistentClient(path="./chromadb")
collection = client.get_or_create_collection(name="Query_builder")

def generate_id(text):
    """Generate a unique ID for each ACL query using SHA256 hash."""
    return hashlib.sha256(text.encode()).hexdigest()

def store_acl_mapping(acl_query, databricks_sql):
    """Store ACL query and its equivalent Databricks SQL in ChromaDB with embeddings."""
    unique_id = generate_id(acl_query)  # Generate a unique ID
    embedding = embedding_model.encode(acl_query).tolist()

    # Avoid duplicate storage
    existing_data = collection.get(ids=[unique_id], include=["documents"])
    if existing_data and existing_data["documents"]:  
        print(f"⚠️ Query already exists, skipping: {acl_query}")
        return  

    collection.add(
        ids=[unique_id],  
        embeddings=[embedding], 
        documents=[acl_query],  # Store ACL query
        metadatas=[{"databricks_sql": databricks_sql}]
    )
    print(f"✅ Stored: {acl_query}")

def load_and_store_json(json_path):
    """Load ACL to Databricks SQL mappings from a JSON file and store in ChromaDB."""
    try:
        with open(json_path, "r", encoding="utf-8") as f:
            data = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError) as e:
        print(f"❌ Error loading JSON file: {e}")
        return

    for entry in data:
        acl_query = entry["input"].strip()
        databricks_sql = entry["output"].strip()
        store_acl_mapping(acl_query, databricks_sql)
    
    print(f"✅ Finished storing {len(data)} ACL queries in ChromaDB.")

# Provide your JSON file path
json_file_path = "extended_acl_to_databricks_dataset.json"
load_and_store_json(json_file_path)
# Out:
# ✅ Stored: AVG Year FROM employees
# ✅ Stored: SORT departments BY Region ASC
# ✅ Stored: FILTER orders WHERE Department = 'Sales'
# ✅ Stored: UNION departments AND employees
# ✅ Stored: HAVING orders WHERE Quantity < 10
# ✅ Stored: FILTER orders WHERE Quantity IN (SELECT Quantity FROM sales WHERE Quantity < 10)
# ✅ Stored: AVG ProductID FROM transactions
# ✅ Stored: SUM HireDate FROM departments
# ✅ Stored: LIMIT products TO 100
# ✅ Stored: WITH cte_39 AS (SELECT Department, Region, ProductID, HireDate, Salary, Year, Quantity, OrderID, Price FROM transactions WHERE Department = 'Sales') SELECT Department, Region, ProductID, HireDate, Salary, Year, Quantity, OrderID, Price FROM cte_39
# ✅ Stored: SELECT Department, OrderID FROM customers WHERE Salary > 50000
# ✅ Stored: SELECT Region, OrderID, Year, Quantity, DATE_TRUNC('year', ProductID) AS Year FROM sales
# ✅ Stored: LIMIT sales TO 20
# ✅ Stored: FILTER departments WHERE Salary IN (SELECT Salary FROM departments WHERE Region = 'North')
# ✅ Stored: SORT departments BY CustomerID DESC
# ✅ Stored: DELETE FROM departments WHERE Salary > 50000
# ✅ Stored: LIMIT transactions TO 100
# ✅ Stored: JOIN departments AND sales ON departments.Price = sales.ProductID
# ✅ Stored: DELETE FROM sales WHERE Year = 2023
# ✅ Stored: AGGREGATE Profit BY Region, Department
# ✅ Stored: EXCEPT customers AND customers
# ✅ Stored: LIMIT transactions TO 10
# ✅ Stored: JOIN orders AND sales ON orders.Department = sales.ProductID
# ✅ Stored: DISTINCT Quantity FROM products
# ✅ Stored: MIN Quantity FROM departments
# ✅ Stored: EXCEPT sales AND departments
# ✅ Stored: MIN Region FROM transactions
# ✅ Stored: SELECT Department, CustomerID, HireDate, Salary, ProductID, OrderID, Quantity, Year, Price, Region, CASE WHEN Region = 'North' THEN 2023 ELSE 10000 END AS ProductID FROM employees
# ✅ Stored: AGGREGATE Profit BY Department
# ✅ Stored: JOIN employees AND orders ON employees.CustomerID = orders.ProductID
# ✅ Stored: MAX ProductID FROM customers
# ✅ Stored: JOIN employees AND departments ON employees.HireDate = departments.ProductID AND employees.Year = departments.HireDate
# ✅ Stored: SELECT Quantity, ROW_NUMBER() OVER (PARTITION BY Year ORDER BY Region) AS row_num FROM products
# ✅ Stored: FILTER products WHERE Year = 2023
# ✅ Stored: DISTINCT Year FROM transactions
# ✅ Stored: EXCEPT employees AND employees
# ✅ Stored: MAX OrderID FROM orders
# ✅ Stored: MAX Quantity FROM products
# ✅ Stored: AVG Quantity FROM transactions
# ✅ Stored: MAX Price FROM products
# ✅ Stored: MIN OrderID FROM sales
# ✅ Stored: FILTER products WHERE ProductID IN (SELECT ProductID FROM departments WHERE Salary > 50000)
# ✅ Stored: EXCEPT sales AND sales
# ✅ Stored: EXCEPT departments AND products
# ✅ Stored: DISTINCT HireDate FROM departments
# ✅ Stored: FILTER orders WHERE HireDate IN (SELECT HireDate FROM sales WHERE Salary > 50000)
# ✅ Stored: SELECT Year, Price, Region, OrderID, Salary, CustomerID, HireDate, Quantity FROM departments WHERE ProductID = (SELECT ProductID FROM sales WHERE Year = 2023)
# ✅ Stored: AVG Quantity FROM employees
# ✅ Stored: FILTER customers WHERE Quantity < 10
# ✅ Stored: SELECT Department, DATE_TRUNC('day', Salary) AS CustomerID FROM customers
# ✅ Stored: WITH cte_61 AS (SELECT Quantity, OrderID, Region, CustomerID, Price, HireDate, Year, Department, ProductID, Salary FROM products WHERE Quantity < 10) SELECT Quantity, OrderID, Region, CustomerID, Price, HireDate, Year, Department, ProductID, Salary FROM cte_61
# ✅ Stored: HAVING customers WHERE Quantity < 10
# ✅ Stored: FILTER sales WHERE HireDate IN (SELECT HireDate FROM employees WHERE Department = 'Sales')
# ✅ Stored: INTERSECT sales AND products
# ✅ Stored: MAX Quantity FROM departments
# ✅ Stored: JOIN sales AND customers ON sales.Salary = customers.Region
# ✅ Stored: INTERSECT departments AND products
# ✅ Stored: SELECT Department, HireDate, ProductID, CONCAT(CustomerID, ' ', Salary) AS Department FROM sales
# ✅ Stored: UNION products AND departments
# ✅ Stored: RENAME products Salary TO OrderID
# ✅ Stored: SELECT ProductID, Department, HireDate, Price, Salary, OrderID, Region FROM products WHERE Year = 2023
# ✅ Stored: FILTER departments WHERE Department = 'Sales'
# ✅ Stored: HAVING products WHERE Salary > 50000
# ✅ Stored: AGGREGATE Revenue BY Department, Year, Region
# ✅ Stored: LIMIT orders TO 20
# ✅ Stored: AGGREGATE Revenue BY Region, Year
# ✅ Stored: SELECT HireDate, Department, Price, CASE WHEN Quantity < 10 THEN 'HR' ELSE 2023 END AS Salary FROM products
# ✅ Stored: AVG Price FROM products
# ✅ Stored: RENAME transactions Quantity TO Price
# ✅ Stored: WITH cte_61 AS (SELECT ProductID, Region, Price FROM orders WHERE Department = 'Sales') SELECT ProductID, Region, Price FROM cte_61
# ✅ Stored: WITH cte_37 AS (SELECT Salary, HireDate, OrderID, Year, ProductID, Quantity, Region, Price, Department FROM sales WHERE Department = 'Sales') SELECT Salary, HireDate, OrderID, Year, ProductID, Quantity, Region, Price, Department FROM cte_37
# ✅ Stored: SELECT OrderID, Region, Quantity, Year, ROW_NUMBER() OVER (PARTITION BY CustomerID ORDER BY Year) AS row_num FROM departments
# ⚠️ Query already exists, skipping: AVG Quantity FROM employees
# ✅ Stored: COUNT sales WHERE Region = 'North'
# ✅ Stored: SELECT ProductID, HireDate, OrderID, Year, ROW_NUMBER() OVER (PARTITION BY Price ORDER BY OrderID) AS row_num FROM customers
# ✅ Stored: JOIN orders AND employees ON orders.ProductID = employees.HireDate
# ✅ Stored: SELECT Quantity, Year, CustomerID, HireDate, CONCAT(OrderID, ' ', OrderID) AS ProductID FROM sales
# ✅ Stored: UPDATE transactions SET CustomerID = 'HR' WHERE Quantity < 10
# ✅ Stored: JOIN employees AND departments ON employees.Salary = departments.Price
# ✅ Stored: AGGREGATE Profit BY Year
# ✅ Stored: WITH cte_23 AS (SELECT OrderID, ProductID FROM customers WHERE Salary > 50000) SELECT OrderID, ProductID FROM cte_23
# ✅ Stored: MAX Department FROM sales
# ✅ Stored: WITH cte_7 AS (SELECT CustomerID, HireDate, Department, OrderID, Price, Quantity, Region, Year, ProductID, Salary FROM transactions WHERE Department = 'Sales') SELECT CustomerID, HireDate, Department, OrderID, Price, Quantity, Region, Year, ProductID, Salary FROM cte_7
# ✅ Stored: SORT orders BY Year DESC
# ✅ Stored: INTERSECT sales AND departments
# ✅ Stored: INTERSECT employees AND sales
# ✅ Stored: DELETE FROM products WHERE Salary > 50000
# ✅ Stored: LIMIT employees TO 50
# ✅ Stored: MIN HireDate FROM departments
# ✅ Stored: EXCEPT products AND employees
# ✅ Stored: DISTINCT HireDate FROM products
# ✅ Stored: SELECT OrderID, Salary, Price, CustomerID, Department, ProductID, HireDate, DATE_TRUNC('year', ProductID) AS ProductID FROM employees
# ✅ Stored: MIN Quantity FROM orders
# ✅ Stored: SELECT Salary, Quantity, HireDate, Region, Department, Year, ProductID, CustomerID, OrderID, Price FROM employees WHERE Year = 2023
# ✅ Stored: SELECT Year, OrderID, DATE_TRUNC('month', HireDate) AS Salary FROM orders
# ✅ Stored: UPDATE departments SET Region = 2023 WHERE Region = 'North'
# ✅ Stored: DELETE FROM transactions WHERE Quantity < 10
# ✅ Stored: DELETE FROM orders WHERE Department = 'Sales'
# ✅ Stored: UPDATE employees SET Price = 'HR' WHERE Year = 2023
# ✅ Stored: SELECT Quantity, Salary, OrderID, CustomerID, Department, ROW_NUMBER() OVER (PARTITION BY Region ORDER BY HireDate) AS row_num FROM orders
# ✅ Stored: MIN ProductID FROM customers
# ✅ Stored: SUM OrderID FROM employees
# ✅ Stored: HAVING employees WHERE Region = 'North'
# ✅ Stored: WITH cte_23 AS (SELECT OrderID, Salary, Year, HireDate, Price, ProductID, Region, CustomerID, Department FROM departments WHERE Region = 'North') SELECT OrderID, Salary, Year, HireDate, Price, ProductID, Region, CustomerID, Department FROM cte_23
# ✅ Stored: SELECT Year, Region, Department, Salary, Price, OrderID, HireDate, Quantity FROM departments WHERE Quantity = (SELECT Quantity FROM employees WHERE Department = 'Sales')
# ✅ Stored: AVG CustomerID FROM transactions
# ✅ Stored: GROUP departments BY Salary, HireDate, Region, Price, ProductID, OrderID, Department, Year, Quantity, CustomerID
# ✅ Stored: FILTER employees WHERE HireDate IN (SELECT HireDate FROM transactions WHERE Region = 'North')
# ✅ Stored: UPDATE sales SET CustomerID = 10000 WHERE Quantity < 10
# ✅ Stored: WITH cte_37 AS (SELECT HireDate, ProductID, OrderID FROM orders WHERE Region = 'North') SELECT HireDate, ProductID, OrderID FROM cte_37
# ✅ Stored: FILTER employees WHERE Department IN (SELECT Department FROM customers WHERE Year = 2023)
# ✅ Stored: SELECT Year, DATE_TRUNC('month', Salary) AS ProductID FROM transactions
# ✅ Stored: SELECT Price, Quantity, Year, HireDate, CustomerID FROM sales WHERE Year = 2023
# ✅ Stored: SELECT ProductID FROM customers WHERE CustomerID = (SELECT CustomerID FROM customers WHERE Quantity < 10)
# ✅ Stored: SELECT ProductID, HireDate, Region, CustomerID, Department, OrderID, Quantity, ROW_NUMBER() OVER (PARTITION BY Department ORDER BY OrderID) AS row_num FROM sales
# ✅ Stored: HAVING employees WHERE Salary > 50000
# ✅ Stored: UPDATE orders SET Department = 'HR' WHERE Salary > 50000
# ✅ Stored: AVG Quantity FROM sales
# ✅ Stored: SELECT HireDate, Region, CustomerID, Price, OrderID, Quantity, Salary, ProductID, Year, DATE_TRUNC('day', CustomerID) AS CustomerID FROM customers
# ✅ Stored: MIN Salary FROM departments
# ✅ Stored: MAX OrderID FROM products
# ✅ Stored: SUM Year FROM transactions
# ✅ Stored: SELECT CustomerID, Department, ProductID, HireDate, Year, Price, Quantity, Region FROM employees WHERE Region = 'North'
# ✅ Stored: SELECT Year FROM customers WHERE Quantity = (SELECT Quantity FROM departments WHERE Salary > 50000)
# ✅ Stored: RENAME transactions Salary TO Salary
# ✅ Stored: SUM OrderID FROM transactions
# ✅ Stored: WITH cte_60 AS (SELECT OrderID, Price, Department, Year FROM employees WHERE Salary > 50000) SELECT OrderID, Price, Department, Year FROM cte_60
# ✅ Stored: AGGREGATE Sales BY Year
# ✅ Stored: FILTER orders WHERE Quantity < 10
# ⚠️ Query already exists, skipping: AGGREGATE Revenue BY Region, Year
# ✅ Stored: AVG CustomerID FROM sales
# ✅ Stored: SELECT Year, HireDate, OrderID, Price, DATE_TRUNC('month', Salary) AS Department FROM transactions
# ✅ Stored: DISTINCT Salary FROM orders
# ✅ Stored: RENAME transactions Year TO HireDate
# ✅ Stored: SORT departments BY Region DESC
# ✅ Stored: JOIN departments AND employees ON departments.OrderID = employees.HireDate AND departments.Salary = employees.HireDate
# ✅ Stored: DISTINCT Price FROM departments
# ✅ Stored: UNION sales AND employees
# ✅ Stored: EXCEPT employees AND sales
# ⚠️ Query already exists, skipping: FILTER orders WHERE Department = 'Sales'
# ✅ Stored: JOIN orders AND orders ON orders.Department = orders.HireDate
# ✅ Stored: UNION products AND products
# ✅ Stored: SELECT CustomerID, Region, Department, HireDate, Price FROM products WHERE Year = 2023
# ✅ Stored: UPDATE departments SET ProductID = 'HR' WHERE Year = 2023
# ✅ Stored: SELECT CustomerID, ProductID, HireDate, Region, Salary, CONCAT(Year, ' ', Region) AS ProductID FROM orders
# ✅ Stored: WITH cte_1 AS (SELECT CustomerID, Region, Department, Price, Year, HireDate, Quantity, OrderID FROM transactions WHERE Quantity < 10) SELECT CustomerID, Region, Department, Price, Year, HireDate, Quantity, OrderID FROM cte_1
# ✅ Stored: SELECT Quantity, Region FROM transactions WHERE Salary = (SELECT Salary FROM sales WHERE Region = 'North')
# ✅ Stored: RENAME sales Department TO Region
# ✅ Stored: RENAME employees Region TO Price
# ✅ Stored: LIMIT transactions TO 20
# ✅ Stored: AGGREGATE Revenue BY Department
# ✅ Stored: FILTER products WHERE Price IN (SELECT Price FROM departments WHERE Region = 'North')
# ✅ Stored: RENAME departments Region TO ProductID
# ✅ Stored: RENAME orders Region TO Region
# ✅ Stored: MAX OrderID FROM customers
# ✅ Stored: AGGREGATE Sales BY Region, Department, Year
# ✅ Stored: RENAME customers Salary TO HireDate
# ✅ Stored: INTERSECT orders AND departments
# ✅ Stored: INTERSECT customers AND employees
# ✅ Stored: SUM Quantity FROM customers
# ✅ Stored: AVG CustomerID FROM orders
# ✅ Stored: SELECT Quantity, Price, Year, ProductID FROM orders WHERE Salary > 50000
# ✅ Stored: FILTER sales WHERE Salary > 50000
# ✅ Stored: SUM HireDate FROM products
# ✅ Stored: SELECT HireDate, OrderID FROM employees WHERE HireDate = (SELECT HireDate FROM employees WHERE Region = 'North')
# ✅ Stored: UPDATE employees SET Department = 2023 WHERE Salary > 50000
# ✅ Stored: GROUP transactions BY Year, Region, CustomerID, Department, HireDate, Salary, ProductID
# ✅ Stored: SELECT Department, CustomerID, Region, Salary, ROW_NUMBER() OVER (PARTITION BY HireDate ORDER BY OrderID) AS row_num FROM customers
# ✅ Stored: DELETE FROM products WHERE Quantity < 10
# ✅ Stored: JOIN products AND customers ON products.Year = customers.CustomerID AND products.CustomerID = customers.Department
# ✅ Stored: UNION employees AND employees
# ✅ Stored: UNION customers AND employees
# ⚠️ Query already exists, skipping: DELETE FROM departments WHERE Salary > 50000
# ✅ Stored: SORT customers BY ProductID DESC
# ✅ Stored: HAVING orders WHERE Department = 'Sales'
# ✅ Stored: GROUP orders BY HireDate, Region
# ✅ Stored: SELECT Year, OrderID, ProductID, Salary, HireDate, Department, ROW_NUMBER() OVER (PARTITION BY HireDate ORDER BY Region) AS row_num FROM sales
# ⚠️ Query already exists, skipping: AGGREGATE Sales BY Year
# ✅ Stored: HAVING products WHERE Department = 'Sales'
# ✅ Stored: GROUP orders BY HireDate, CustomerID, Region, Price, Salary, Quantity, OrderID, Department, Year, ProductID
# ✅ Stored: JOIN transactions AND orders ON transactions.Quantity = orders.CustomerID
# ✅ Stored: RENAME customers Quantity TO HireDate
# ✅ Stored: UNION transactions AND employees
# ✅ Stored: SORT sales BY Price ASC
# ⚠️ Query already exists, skipping: HAVING orders WHERE Department = 'Sales'
# ✅ Stored: HAVING products WHERE Year = 2023
# ✅ Stored: MAX Salary FROM transactions
# ✅ Stored: HAVING transactions WHERE Quantity < 10
# ✅ Stored: JOIN orders AND orders ON orders.CustomerID = orders.Price AND orders.Salary = orders.Price
# ✅ Stored: INTERSECT transactions AND customers
# ✅ Stored: SELECT Salary, DATE_TRUNC('day', Department) AS ProductID FROM products
# ✅ Stored: HAVING departments WHERE Year = 2023
# ✅ Stored: FILTER employees WHERE CustomerID IN (SELECT CustomerID FROM employees WHERE Department = 'Sales')
# ✅ Stored: FILTER employees WHERE Region = 'North'
# ✅ Stored: INTERSECT orders AND employees
# ✅ Stored: SELECT Price, Region, Department, ProductID, ROW_NUMBER() OVER (PARTITION BY Region ORDER BY ProductID) AS row_num FROM transactions
# ✅ Stored: FILTER orders WHERE Region = 'North'
# ✅ Stored: UNION orders AND transactions
# ✅ Stored: GROUP orders BY Department, Region, HireDate, Price, ProductID, Year, Salary, CustomerID, OrderID, Quantity
# ✅ Stored: AGGREGATE Revenue BY Year
# ✅ Stored: SELECT Salary, Year, HireDate, ProductID FROM sales WHERE Department = 'Sales'
# ✅ Stored: SORT sales BY Region ASC
# ✅ Stored: SELECT Quantity, OrderID, Department, CustomerID, Year, HireDate, Price FROM orders WHERE Region = (SELECT Region FROM sales WHERE Salary > 50000)
# ✅ Stored: SELECT Quantity, ProductID, OrderID, Price, CustomerID, HireDate, Department, Year, Region FROM sales WHERE OrderID = (SELECT OrderID FROM sales WHERE Salary > 50000)
# ✅ Stored: AVG OrderID FROM products
# ✅ Stored: MAX Price FROM transactions
# ✅ Stored: AGGREGATE Profit BY Year, Region
# ✅ Stored: LIMIT transactions TO 50
# ✅ Stored: WITH cte_3 AS (SELECT HireDate, ProductID, Region, Quantity, Price, Department, Salary, Year, CustomerID, OrderID FROM departments WHERE Department = 'Sales') SELECT HireDate, ProductID, Region, Quantity, Price, Department, Salary, Year, CustomerID, OrderID FROM cte_3
# ✅ Stored: SELECT ProductID, Price, Region, Quantity, OrderID, Department, Year, HireDate, DATE_TRUNC('year', Department) AS Price FROM transactions
# ✅ Stored: SELECT Year, Price, Region, HireDate, ProductID, Salary, OrderID, Quantity, Department, CustomerID, ROW_NUMBER() OVER (PARTITION BY HireDate ORDER BY Region) AS row_num FROM orders
# ⚠️ Query already exists, skipping: MIN Region FROM transactions
# ✅ Stored: LIMIT orders TO 50
# ✅ Stored: SUM Quantity FROM products
# ✅ Stored: LIMIT sales TO 50
# ✅ Stored: SELECT OrderID, Quantity, Price, HireDate, Department, CustomerID, ProductID, Salary, Year, Region FROM transactions WHERE OrderID = (SELECT OrderID FROM transactions WHERE Department = 'Sales')
# ✅ Stored: AVG Quantity FROM products
# ✅ Stored: SUM Salary FROM orders
# ✅ Stored: AGGREGATE Profit BY Region
# ✅ Stored: JOIN employees AND transactions ON employees.HireDate = transactions.OrderID
# ✅ Stored: AGGREGATE Sales BY Department, Region
# ✅ Stored: COUNT employees WHERE Department = 'Sales'
# ✅ Stored: SELECT ProductID, Quantity, Department, HireDate, Salary FROM sales WHERE CustomerID = (SELECT CustomerID FROM employees WHERE Year = 2023)
# ✅ Stored: DISTINCT Year FROM orders
# ✅ Stored: SUM HireDate FROM sales
# ✅ Stored: UNION departments AND customers
# ⚠️ Query already exists, skipping: MIN Quantity FROM orders
# ✅ Stored: LIMIT sales TO 100
# ✅ Stored: AGGREGATE Sales BY Region
# ✅ Stored: HAVING departments WHERE Salary > 50000
# ✅ Stored: JOIN orders AND products ON orders.Department = products.Department
# ⚠️ Query already exists, skipping: UNION sales AND employees
# ✅ Stored: SELECT Region, Salary, CustomerID FROM sales WHERE Salary > 50000
# ✅ Stored: SELECT Region, CustomerID, Salary FROM products WHERE CustomerID = (SELECT CustomerID FROM orders WHERE Year = 2023)
# ✅ Stored: SELECT Department, ProductID, Quantity, HireDate, Price, Salary, ROW_NUMBER() OVER (PARTITION BY Region ORDER BY Department) AS row_num FROM transactions
# ✅ Stored: JOIN transactions AND orders ON transactions.Price = orders.HireDate
# ✅ Stored: AVG CustomerID FROM departments
# ⚠️ Query already exists, skipping: AGGREGATE Revenue BY Department
# ✅ Stored: WITH cte_42 AS (SELECT Quantity, OrderID, HireDate, Department, ProductID, Year, CustomerID FROM orders WHERE Department = 'Sales') SELECT Quantity, OrderID, HireDate, Department, ProductID, Year, CustomerID FROM cte_42
# ✅ Stored: INTERSECT orders AND products
# ✅ Stored: RENAME products OrderID TO CustomerID
# ✅ Stored: GROUP employees BY Price, HireDate, Department
# ✅ Stored: JOIN employees AND customers ON employees.Salary = customers.Quantity
# ✅ Stored: SELECT CustomerID, Region, Department, HireDate, Salary, ProductID, OrderID, CONCAT(Quantity, ' ', Price) AS HireDate FROM transactions
# ✅ Stored: INTERSECT transactions AND sales
# ⚠️ Query already exists, skipping: LIMIT sales TO 100
# ✅ Stored: AVG ProductID FROM employees
# ✅ Stored: SELECT Price, CustomerID, Year, CONCAT(Salary, ' ', Price) AS Price FROM departments
# ✅ Stored: JOIN products AND departments ON products.Year = departments.Department
# ⚠️ Query already exists, skipping: LIMIT sales TO 20
# ✅ Stored: SELECT HireDate, Salary, Department, Price, Quantity, CustomerID, Region, ProductID, ROW_NUMBER() OVER (PARTITION BY Region ORDER BY OrderID) AS row_num FROM departments
# ✅ Stored: DELETE FROM sales WHERE Department = 'Sales'
# ✅ Stored: RENAME sales Salary TO Year
# ✅ Stored: WITH cte_45 AS (SELECT Quantity, Year, OrderID, HireDate, Price, CustomerID, ProductID, Salary FROM employees WHERE Department = 'Sales') SELECT Quantity, Year, OrderID, HireDate, Price, CustomerID, ProductID, Salary FROM cte_45
# ✅ Stored: RENAME orders OrderID TO Salary
# ✅ Stored: SELECT Quantity, Department, Salary, Year, HireDate, Price, CustomerID, OrderID, ProductID, Region FROM customers WHERE Salary = (SELECT Salary FROM transactions WHERE Department = 'Sales')
# ✅ Stored: DISTINCT Quantity FROM sales
# ✅ Stored: UNION sales AND orders
# ✅ Stored: EXCEPT products AND customers
# ✅ Stored: UPDATE employees SET Price = 'HR' WHERE Department = 'Sales'
# ✅ Stored: SELECT Salary, OrderID, ProductID, CustomerID, Year, HireDate, Region, Price, DATE_TRUNC('day', Price) AS OrderID FROM departments
# ✅ Stored: FILTER employees WHERE Year = 2023
# ✅ Stored: SELECT ProductID, CONCAT(Salary, ' ', ProductID) AS CustomerID FROM orders
# ✅ Stored: EXCEPT products AND sales
# ✅ Stored: JOIN sales AND orders ON sales.Quantity = orders.Quantity
# ✅ Stored: MAX CustomerID FROM employees
# ✅ Stored: SORT customers BY Department ASC
# ✅ Stored: RENAME transactions ProductID TO CustomerID
# ✅ Stored: HAVING departments WHERE Department = 'Sales'
# ✅ Stored: COUNT orders WHERE Quantity < 10
# ✅ Stored: JOIN sales AND products ON sales.OrderID = products.Salary AND sales.Region = products.OrderID
# ✅ Stored: INTERSECT products AND departments
# ✅ Stored: SORT transactions BY ProductID DESC
# ✅ Stored: SELECT OrderID, HireDate, Region, CustomerID, Department, Price, ProductID, ROW_NUMBER() OVER (PARTITION BY Price ORDER BY ProductID) AS row_num FROM customers
# ✅ Stored: UNION transactions AND products
# ✅ Stored: SORT customers BY Year DESC
# ✅ Stored: FILTER departments WHERE Region IN (SELECT Region FROM employees WHERE Salary > 50000)
# ✅ Stored: FILTER customers WHERE Salary IN (SELECT Salary FROM products WHERE Region = 'North')
# ✅ Stored: DISTINCT ProductID FROM employees
# ✅ Stored: AVG HireDate FROM customers
# ✅ Stored: UPDATE sales SET Quantity = 10000 WHERE Department = 'Sales'
# ✅ Stored: JOIN departments AND sales ON departments.Price = sales.Region AND departments.Year = sales.ProductID
# ✅ Stored: JOIN customers AND employees ON customers.Salary = employees.Year
# ✅ Stored: AGGREGATE Sales BY Year, Region
# ✅ Stored: SELECT Department, Year, CustomerID, Salary, Price, ROW_NUMBER() OVER (PARTITION BY HireDate ORDER BY ProductID) AS row_num FROM sales
# ✅ Stored: SORT transactions BY Salary ASC
# ✅ Stored: JOIN departments AND transactions ON departments.Price = transactions.CustomerID AND departments.HireDate = transactions.OrderID
# ✅ Stored: SELECT Region, Year, CustomerID, OrderID, HireDate, CASE WHEN Department = 'Sales' THEN 'HR' ELSE 10000 END AS ProductID FROM employees
# ✅ Stored: FILTER customers WHERE Year = 2023
# ✅ Stored: SELECT Salary, CustomerID, CASE WHEN Region = 'North' THEN 'HR' ELSE 10000 END AS Price FROM sales
# ✅ Stored: SELECT OrderID, CASE WHEN Department = 'Sales' THEN 'HR' ELSE 'HR' END AS ProductID FROM transactions
# ✅ Stored: SELECT OrderID, Region FROM products WHERE Quantity = (SELECT Quantity FROM sales WHERE Year = 2023)
# ✅ Stored: JOIN employees AND departments ON employees.Price = departments.Department AND employees.OrderID = departments.ProductID
# ✅ Stored: UPDATE departments SET Region = 10000 WHERE Quantity < 10
# ✅ Stored: COUNT orders WHERE Region = 'North'
# ✅ Stored: WITH cte_6 AS (SELECT OrderID, Salary, Year, CustomerID FROM employees WHERE Year = 2023) SELECT OrderID, Salary, Year, CustomerID FROM cte_6
# ✅ Stored: SELECT CustomerID, Year, OrderID, Price, Department, Quantity, HireDate, Region, ProductID, Salary, ROW_NUMBER() OVER (PARTITION BY Salary ORDER BY Price) AS row_num FROM orders
# ✅ Stored: COUNT transactions WHERE Quantity < 10
# ✅ Stored: SORT sales BY ProductID ASC
# ✅ Stored: UNION products AND customers
# ✅ Stored: UPDATE employees SET Quantity = 10000 WHERE Department = 'Sales'
# ✅ Stored: MIN Price FROM departments
# ✅ Stored: GROUP transactions BY ProductID, Region, OrderID, HireDate, CustomerID, Year
# ✅ Stored: DISTINCT HireDate FROM transactions
# ✅ Stored: SORT sales BY CustomerID ASC
# ✅ Stored: RENAME sales CustomerID TO ProductID
# ⚠️ Query already exists, skipping: LIMIT products TO 100
# ✅ Stored: COUNT employees WHERE Salary > 50000
# ✅ Stored: JOIN products AND orders ON products.Department = orders.Year AND products.Salary = orders.ProductID
# ✅ Stored: GROUP orders BY Department, Year, ProductID, Price, HireDate, Region, Quantity, Salary
# ✅ Stored: COUNT orders WHERE Department = 'Sales'
# ✅ Stored: DELETE FROM transactions WHERE Region = 'North'
# ✅ Stored: WITH cte_73 AS (SELECT Quantity, Salary, CustomerID, Price, OrderID, Year, ProductID, HireDate FROM sales WHERE Year = 2023) SELECT Quantity, Salary, CustomerID, Price, OrderID, Year, ProductID, HireDate FROM cte_73
# ✅ Stored: DISTINCT Department FROM products
# ✅ Stored: FILTER sales WHERE Year = 2023
# ✅ Stored: SELECT HireDate, Salary, CustomerID, Region, ProductID, Year FROM employees WHERE Region = 'North'
# ✅ Stored: WITH cte_61 AS (SELECT OrderID, HireDate, Quantity, Region, Price, Salary, Department, Year, ProductID, CustomerID FROM orders WHERE Department = 'Sales') SELECT OrderID, HireDate, Quantity, Region, Price, Salary, Department, Year, ProductID, CustomerID FROM cte_61
# ✅ Stored: SUM Department FROM employees
# ✅ Stored: SELECT Year, Region, Department, Quantity, HireDate, Price, ProductID, Salary, OrderID, CONCAT(Price, ' ', Quantity) AS Region FROM products
# ✅ Stored: SUM CustomerID FROM orders
# ✅ Stored: AVG Salary FROM transactions
# ✅ Stored: SELECT Salary, ProductID, HireDate, Quantity, Department, CASE WHEN Quantity < 10 THEN 'HR' ELSE 2023 END AS HireDate FROM departments
# ✅ Stored: EXCEPT employees AND products
# ✅ Stored: JOIN transactions AND products ON transactions.CustomerID = products.Price
# ✅ Stored: SORT transactions BY Salary DESC
# ✅ Stored: SORT employees BY CustomerID ASC
# ✅ Stored: WITH cte_76 AS (SELECT Price FROM departments WHERE Year = 2023) SELECT Price FROM cte_76
# ✅ Stored: SELECT ProductID, Quantity, Year, CustomerID, Department FROM products WHERE Year = 2023
# ✅ Stored: DISTINCT Year FROM sales
# ✅ Stored: MIN OrderID FROM products
# ✅ Stored: SELECT OrderID, Salary, Year, CustomerID, Price, ROW_NUMBER() OVER (PARTITION BY OrderID ORDER BY Price) AS row_num FROM employees
# ✅ Stored: SELECT Department FROM orders WHERE HireDate = (SELECT HireDate FROM customers WHERE Region = 'North')
# ⚠️ Query already exists, skipping: DISTINCT Quantity FROM sales
# ✅ Stored: DISTINCT Price FROM customers
# ✅ Stored: LIMIT departments TO 20
# ✅ Stored: FILTER products WHERE Region = 'North'
# ✅ Stored: UNION customers AND transactions
# ✅ Stored: COUNT sales WHERE Quantity < 10
# ✅ Stored: MIN Salary FROM employees
# ✅ Stored: MIN Price FROM orders
# ✅ Stored: SELECT Price, Salary, CustomerID, Year, ROW_NUMBER() OVER (PARTITION BY Salary ORDER BY Salary) AS row_num FROM sales
# ⚠️ Query already exists, skipping: MAX OrderID FROM products
# ✅ Stored: MIN HireDate FROM customers
# ✅ Stored: WITH cte_77 AS (SELECT ProductID, Salary FROM sales WHERE Region = 'North') SELECT ProductID, Salary FROM cte_77
# ✅ Stored: JOIN orders AND employees ON orders.Salary = employees.Quantity AND orders.Year = employees.ProductID
# ✅ Stored: DISTINCT Department FROM customers
# ✅ Stored: SELECT Year, HireDate, Region, CustomerID, Department, ProductID FROM orders WHERE ProductID = (SELECT ProductID FROM transactions WHERE Region = 'North')
# ✅ Stored: AGGREGATE Revenue BY Region, Year, Department
# ✅ Stored: UNION customers AND orders
# ✅ Stored: SELECT Region, Department, Price, Year, Salary, OrderID, HireDate, CustomerID, DATE_TRUNC('day', ProductID) AS Region FROM products
# ⚠️ Query already exists, skipping: UNION orders AND transactions
# ✅ Stored: RENAME transactions Price TO Region
# ✅ Stored: UPDATE sales SET OrderID = 'HR' WHERE Region = 'North'
# ⚠️ Query already exists, skipping: UNION sales AND orders
# ✅ Stored: JOIN transactions AND transactions ON transactions.ProductID = transactions.Region AND transactions.CustomerID = transactions.HireDate
# ✅ Stored: UNION transactions AND orders
# ✅ Stored: JOIN customers AND products ON customers.Price = products.HireDate
# ⚠️ Query already exists, skipping: UNION transactions AND products
# ✅ Stored: DISTINCT Department FROM transactions
# ✅ Stored: JOIN customers AND transactions ON customers.CustomerID = transactions.Salary AND customers.OrderID = transactions.Quantity
# ✅ Stored: DELETE FROM transactions WHERE Salary > 50000
# ✅ Stored: HAVING departments WHERE Quantity < 10
# ✅ Stored: SELECT Price, ProductID, Salary, Quantity, CustomerID, Region, ROW_NUMBER() OVER (PARTITION BY Salary ORDER BY Price) AS row_num FROM sales
# ✅ Stored: GROUP customers BY Price, Region, Year, OrderID, Salary, Department
# ✅ Stored: SORT products BY Region DESC
# ✅ Stored: SELECT Department, CustomerID, ProductID, Salary, OrderID, HireDate, Price FROM employees WHERE Year = (SELECT Year FROM products WHERE Quantity < 10)
# ✅ Stored: GROUP employees BY Quantity, Salary, Price, Department, Region, HireDate, OrderID, ProductID, Year, CustomerID
# ✅ Stored: RENAME customers Region TO HireDate
# ⚠️ Query already exists, skipping: AVG Quantity FROM products
# ✅ Stored: DELETE FROM customers WHERE Department = 'Sales'
# ✅ Stored: SELECT Department, ProductID, Year, Price, CustomerID, OrderID, Region, HireDate, Quantity, Salary FROM products WHERE Department = 'Sales'
# ✅ Stored: SUM Salary FROM transactions
# ✅ Stored: JOIN sales AND departments ON sales.CustomerID = departments.Region AND sales.OrderID = departments.Year
# ✅ Stored: INTERSECT customers AND sales
# ⚠️ Query already exists, skipping: LIMIT transactions TO 50
# ✅ Stored: WITH cte_96 AS (SELECT Salary, Region, Quantity, CustomerID, OrderID, HireDate, Year, Price FROM products WHERE Quantity < 10) SELECT Salary, Region, Quantity, CustomerID, OrderID, HireDate, Year, Price FROM cte_96
# ✅ Stored: UNION orders AND products
# ✅ Stored: SELECT Region, ProductID, HireDate, ROW_NUMBER() OVER (PARTITION BY Price ORDER BY OrderID) AS row_num FROM orders
# ✅ Stored: LIMIT products TO 10
# ✅ Stored: DELETE FROM customers WHERE Region = 'North'
# ✅ Stored: DISTINCT Region FROM sales
# ✅ Stored: FILTER transactions WHERE CustomerID IN (SELECT CustomerID FROM orders WHERE Region = 'North')
# ✅ Stored: SELECT Price, Department, ProductID, HireDate, CustomerID, Year, Salary, Quantity, OrderID, ROW_NUMBER() OVER (PARTITION BY Region ORDER BY Price) AS row_num FROM orders
# ✅ Stored: AVG Region FROM departments
# ✅ Stored: SUM Department FROM transactions
# ✅ Stored: RENAME customers Department TO ProductID
# ⚠️ Query already exists, skipping: MAX Price FROM products
# ⚠️ Query already exists, skipping: AGGREGATE Revenue BY Department
# ✅ Stored: INTERSECT departments AND customers
# ⚠️ Query already exists, skipping: DISTINCT Salary FROM orders
# ✅ Stored: MAX Salary FROM orders
# ✅ Stored: UPDATE customers SET Salary = 'HR' WHERE Salary > 50000
# ✅ Stored: WITH cte_96 AS (SELECT Price, OrderID, CustomerID, ProductID FROM orders WHERE Year = 2023) SELECT Price, OrderID, CustomerID, ProductID FROM cte_96
# ✅ Stored: HAVING customers WHERE Region = 'North'
# ✅ Stored: SELECT Quantity, Region, Price, HireDate, Salary, Year, Department, ROW_NUMBER() OVER (PARTITION BY ProductID ORDER BY CustomerID) AS row_num FROM orders
# ✅ Stored: MIN Salary FROM transactions
# ✅ Stored: INTERSECT customers AND customers
# ✅ Stored: WITH cte_7 AS (SELECT Salary FROM transactions WHERE Quantity < 10) SELECT Salary FROM cte_7
# ✅ Stored: AGGREGATE Revenue BY Region
# ✅ Stored: EXCEPT employees AND customers
# ✅ Stored: SELECT Price, Year, ROW_NUMBER() OVER (PARTITION BY Department ORDER BY Salary) AS row_num FROM sales
# ⚠️ Query already exists, skipping: AVG Year FROM employees
# ✅ Stored: SORT products BY Year DESC
# ✅ Stored: JOIN sales AND employees ON sales.Price = employees.OrderID
# ✅ Stored: SELECT Year, Department, ProductID, DATE_TRUNC('month', Salary) AS Department FROM customers
# ✅ Stored: DISTINCT Salary FROM employees
# ⚠️ Query already exists, skipping: AGGREGATE Sales BY Region
# ✅ Stored: SELECT Department, OrderID, ProductID, Quantity, HireDate, Region, Price, Year, CustomerID, Salary, CASE WHEN Region = 'North' THEN 2023 ELSE 10000 END AS Salary FROM products
# ✅ Stored: FILTER orders WHERE OrderID IN (SELECT OrderID FROM products WHERE Department = 'Sales')
# ✅ Stored: UPDATE transactions SET Price = 10000 WHERE Salary > 50000
# ✅ Stored: SELECT Quantity, CustomerID FROM products WHERE Department = 'Sales'
# ✅ Stored: SELECT Quantity, CONCAT(Price, ' ', HireDate) AS CustomerID FROM employees
# ✅ Stored: FILTER customers WHERE ProductID IN (SELECT ProductID FROM products WHERE Quantity < 10)
# ✅ Stored: DISTINCT HireDate FROM sales
# ✅ Stored: UPDATE products SET CustomerID = 10000 WHERE Year = 2023
# ⚠️ Query already exists, skipping: LIMIT employees TO 50
# ✅ Stored: UNION departments AND sales
# ✅ Stored: SELECT Salary, Quantity FROM departments WHERE OrderID = (SELECT OrderID FROM customers WHERE Salary > 50000)
# ✅ Stored: SELECT Year, Price, Quantity, HireDate, CustomerID, Region, OrderID, CONCAT(HireDate, ' ', Department) AS OrderID FROM sales
# ✅ Stored: GROUP employees BY Quantity, Salary, ProductID, Year, OrderID, Department, CustomerID, HireDate
# ✅ Stored: DISTINCT Department FROM sales
# ✅ Stored: MAX HireDate FROM departments
# ✅ Stored: SELECT ProductID, Quantity, Year, HireDate, CustomerID, CASE WHEN Department = 'Sales' THEN 2023 ELSE 10000 END AS Price FROM departments
# ✅ Stored: SELECT Department, Region, Year, CustomerID, ROW_NUMBER() OVER (PARTITION BY Quantity ORDER BY Department) AS row_num FROM employees
# ✅ Stored: SELECT OrderID, Year, CONCAT(Region, ' ', Quantity) AS OrderID FROM employees
# ⚠️ Query already exists, skipping: AGGREGATE Sales BY Region, Department, Year
# ⚠️ Query already exists, skipping: HAVING products WHERE Year = 2023
# ⚠️ Query already exists, skipping: UNION departments AND sales
# ✅ Stored: FILTER sales WHERE CustomerID IN (SELECT CustomerID FROM sales WHERE Department = 'Sales')
# ✅ Stored: SELECT Quantity, Department, Year, HireDate, OrderID, Region, ProductID FROM transactions WHERE Salary > 50000
# ⚠️ Query already exists, skipping: RENAME orders Region TO Region
# ✅ Stored: WITH cte_10 AS (SELECT HireDate, ProductID, Price, OrderID, Department, Salary, Region, Year, CustomerID FROM employees WHERE Quantity < 10) SELECT HireDate, ProductID, Price, OrderID, Department, Salary, Region, Year, CustomerID FROM cte_10
# ✅ Stored: EXCEPT orders AND sales
# ⚠️ Query already exists, skipping: DELETE FROM products WHERE Quantity < 10
# ✅ Stored: WITH cte_78 AS (SELECT OrderID, HireDate, Region, Price, CustomerID, Quantity, Salary, Year FROM orders WHERE Region = 'North') SELECT OrderID, HireDate, Region, Price, CustomerID, Quantity, Salary, Year FROM cte_78
# ✅ Stored: SELECT CustomerID, HireDate, Year, ProductID, Region, Salary, OrderID, Department, Price, Quantity FROM orders WHERE Salary > 50000
# ⚠️ Query already exists, skipping: UNION orders AND transactions
# ⚠️ Query already exists, skipping: COUNT orders WHERE Region = 'North'
# ✅ Stored: SELECT Salary, Region, ProductID, Department, HireDate, CustomerID FROM products WHERE Region = 'North'
# ✅ Stored: GROUP products BY Quantity, HireDate, Region, Price, Year, CustomerID, ProductID, OrderID, Salary
# ✅ Stored: MIN Department FROM orders
# ⚠️ Query already exists, skipping: COUNT orders WHERE Region = 'North'
# ✅ Stored: AGGREGATE Profit BY Year, Department
# ⚠️ Query already exists, skipping: FILTER orders WHERE Department = 'Sales'
# ✅ Stored: DELETE FROM products WHERE Region = 'North'
# ✅ Stored: SELECT Region, ProductID, Department, HireDate, Salary, Quantity, OrderID, CustomerID, Year, CASE WHEN Salary > 50000 THEN 10000 ELSE 2023 END AS Quantity FROM customers
# ✅ Stored: UPDATE sales SET Region = 'HR' WHERE Region = 'North'
# ✅ Stored: SELECT HireDate, Region, Salary, Year, CustomerID, ProductID, OrderID, Department, Quantity, Price, CONCAT(OrderID, ' ', Region) AS Salary FROM products
# ✅ Stored: AVG CustomerID FROM employees
# ✅ Stored: UPDATE orders SET OrderID = 10000 WHERE Salary > 50000
# ✅ Stored: AVG Department FROM departments
# ✅ Stored: SELECT Department, HireDate, Price, ProductID, Salary FROM sales WHERE Salary = (SELECT Salary FROM employees WHERE Department = 'Sales')
# ✅ Stored: FILTER employees WHERE Quantity < 10
# ✅ Stored: MAX CustomerID FROM orders
# ✅ Stored: SELECT Price, Year FROM departments WHERE Salary > 50000
# ✅ Stored: SELECT ProductID, Salary, Price, HireDate, CONCAT(ProductID, ' ', CustomerID) AS OrderID FROM departments
# ✅ Stored: FILTER sales WHERE ProductID IN (SELECT ProductID FROM products WHERE Region = 'North')
# ✅ Stored: SELECT ProductID, CustomerID, Department FROM departments WHERE Salary = (SELECT Salary FROM products WHERE Department = 'Sales')
# ✅ Stored: MAX Quantity FROM transactions
# ⚠️ Query already exists, skipping: FILTER employees WHERE Region = 'North'
# ✅ Stored: SELECT Salary, Department, CustomerID, Quantity, OrderID, HireDate, Year, ProductID, Region, Price, DATE_TRUNC('month', Department) AS Department FROM customers
# ⚠️ Query already exists, skipping: DISTINCT Quantity FROM sales
# ✅ Stored: SELECT HireDate, Department, Quantity, Region, Price, Salary, OrderID, CASE WHEN Department = 'Sales' THEN 2023 ELSE 2023 END AS Quantity FROM employees
# ✅ Stored: AGGREGATE Profit BY Year, Region, Department
# ✅ Stored: SELECT Price, CustomerID, Salary, Year FROM orders WHERE ProductID = (SELECT ProductID FROM products WHERE Salary > 50000)
# ✅ Stored: UNION employees AND transactions
# ✅ Stored: GROUP products BY Region, HireDate, Year, Price, OrderID, Salary
# ✅ Stored: DISTINCT Price FROM sales
# ✅ Stored: SELECT HireDate, Salary, Quantity, OrderID, ProductID, CustomerID, Department, Region, Year, CONCAT(Department, ' ', HireDate) AS Price FROM products
# ⚠️ Query already exists, skipping: UNION customers AND employees
# ⚠️ Query already exists, skipping: SUM Department FROM transactions
# ⚠️ Query already exists, skipping: INTERSECT products AND departments
# ✅ Stored: SELECT ProductID, Salary, Price, OrderID, Department, CONCAT(Quantity, ' ', OrderID) AS Year FROM orders
# ✅ Stored: JOIN departments AND transactions ON departments.Region = transactions.OrderID AND departments.ProductID = transactions.Region
# ✅ Stored: EXCEPT customers AND sales
# ✅ Stored: EXCEPT customers AND products
# ✅ Stored: FILTER customers WHERE ProductID IN (SELECT ProductID FROM products WHERE Year = 2023)
# ✅ Stored: SELECT Region FROM customers WHERE Region = (SELECT Region FROM customers WHERE Department = 'Sales')
# ✅ Stored: SELECT HireDate, Price, Year, Department FROM customers WHERE Year = (SELECT Year FROM transactions WHERE Quantity < 10)
# ✅ Stored: SELECT OrderID, Price, Salary, Department, Year, Quantity, ProductID, Region, CASE WHEN Region = 'North' THEN 2023 ELSE 10000 END AS Year FROM transactions
# ✅ Stored: FILTER employees WHERE ProductID IN (SELECT ProductID FROM departments WHERE Region = 'North')
# ✅ Stored: SELECT Region FROM sales WHERE ProductID = (SELECT ProductID FROM employees WHERE Salary > 50000)
# ✅ Stored: UPDATE employees SET Price = 'HR' WHERE Quantity < 10
# ⚠️ Query already exists, skipping: SUM Salary FROM transactions
# ✅ Stored: LIMIT customers TO 10
# ✅ Stored: AVG ProductID FROM departments
# ✅ Stored: SELECT Region, DATE_TRUNC('month', Year) AS Salary FROM sales
# ⚠️ Query already exists, skipping: UNION customers AND transactions
# ✅ Stored: SORT employees BY Department DESC
# ✅ Stored: EXCEPT orders AND products
# ✅ Stored: INTERSECT sales AND orders
# ✅ Stored: SELECT Price, HireDate, CustomerID, OrderID, ProductID, Quantity, Salary, Department, DATE_TRUNC('year', Salary) AS Year FROM departments
# ✅ Stored: INTERSECT departments AND departments
# ✅ Stored: SELECT Salary, Region, ROW_NUMBER() OVER (PARTITION BY Department ORDER BY Region) AS row_num FROM products
# ⚠️ Query already exists, skipping: MIN Salary FROM departments
# ✅ Stored: SUM Quantity FROM departments
# ✅ Stored: COUNT departments WHERE Year = 2023
# ✅ Stored: SELECT Price, Region, HireDate, DATE_TRUNC('year', Quantity) AS Region FROM transactions
# ⚠️ Query already exists, skipping: DISTINCT Department FROM customers
# ✅ Stored: SELECT OrderID, Year, ProductID, HireDate, DATE_TRUNC('year', Price) AS Region FROM customers
# ✅ Stored: APPEND employees TO archived_employees
# ✅ Stored: MERGE transactions WITH sales ON transactions.OrderID = sales.OrderID
# ✅ Stored: EXTRACT Year FROM sales
# ✅ Stored: CALCULATE MEDIAN Salary FROM employees
# ✅ Stored: EXPORT transactions TO 's3://bucket/transactions.csv'
# ✅ Stored: ALTER TABLE employees ADD COLUMN Age INT
# ✅ Stored: ALTER TABLE sales DROP COLUMN Discount
# ✅ Stored: JOIN customers AND orders ON customers.CustomerID = orders.CustomerID LEFT
# ✅ Stored: JOIN employees AND departments ON employees.DepartmentID = departments.DepartmentID FULL
# ✅ Stored: FILTER sales WHERE OrderDate BETWEEN '2023-01-01' AND '2023-12-31'
# ✅ Stored: FILTER employees WHERE Name LIKE 'A%'
# ✅ Stored: SORT transactions BY OrderDate DESC LIMIT 50
# ✅ Stored: GROUP sales BY Year, Region HAVING SUM(Revenue) > 1000000
# ✅ Stored: UPDATE employees SET Salary = Salary * 1.1 WHERE PerformanceRating = 'Excellent'
# ✅ Stored: DELETE FROM transactions WHERE Status = 'Cancelled'
# ✅ Finished storing 515 ACL queries in ChromaDB.

# %%
import numpy as np

def retrieve_similar_queries(acl_query, top_k=3):
    """Retrieve the most similar stored ACL queries from ChromaDB."""
    embedding = embedding_model.encode(acl_query).tolist()

    # Perform similarity search in ChromaDB
    results = collection.query(
        query_embeddings=[embedding],
        n_results=top_k,  # Get top-k similar queries
        include=["documents", "metadatas"]  # Fetch stored queries & their metadata
    )

    # Extract best matching queries and SQL outputs
    similar_queries = results["documents"][0]  # List of matching ACL queries
    metadata = results["metadatas"][0]  # List of Databricks SQL outputs

    # Handle case where no match is found
    if not similar_queries or not metadata:
        print("⚠️ No similar queries found.")
        return None

    # Return top match
    return metadata[0]["databricks_sql"]  # Best match's Databricks SQL

# %%
# Example ACL query to convert
query = "select orders WHERE Region = 'North'"

# Retrieve and print the best matching Databricks SQL query
converted_query = retrieve_similar_queries(query)
print("🔄 Converted Databricks SQL:", converted_query)
# Out:
# 🔄 Converted Databricks SQL: SELECT * FROM orders WHERE Region = 'North';

# %%
import ollama

def refine_query_with_ollama(acl_query):
    """Refine ACL to Databricks SQL conversion using Ollama model."""
    
    retrieved_sql = retrieve_similar_queries(acl_query)  # Ensure this function is defined
    
    if not retrieved_sql:
        return "⚠️ No matching query found."

    prompt = f"""
    Convert the following ACL query into an optimized Databricks SQL query:
    
    ACL Query: {acl_query}
    
    Based on a similar existing query:
    {retrieved_sql}

    Ensure the output is syntactically correct, optimized, and adheres to best SQL practices.
    """

    try:
        response = ollama.chat(
            model="deepseek-r1",
            messages=[{"role": "user", "content": prompt}],
            options={"temperature": 0}  # Ensure deterministic output
        )
        return response["message"]["content"]
    
    except Exception as e:
        return f"⚠️ Error processing query: {str(e)}"

# Example usage
acl_query = "COUNT orders WHERE Region = 'North'"
databricks_query = refine_query_with_ollama(acl_query)
print("🚀 Final Databricks Query:", databricks_query)
# Out:
# 🚀 Final Databricks Query: <think>
# Okay, so I need to convert an ACL query into an optimized Databricks SQL query. The original ACL query is "COUNT orders WHERE Region = 'North'". There's also a similar existing query that serves as a reference: "SELECT COUNT(*) FROM orders WHERE Region = 'North';".
#
# First, I should understand what the difference is between these two queries. The ACL version seems to be using just "COUNT orders", which might not specify the column clearly. In SQL terms, it's more precise to use "COUNT(order_id)" or something similar because it specifies exactly which column we're counting.
#
# Looking at the existing query, it uses SELECT COUNT(*) FROM orders WHERE Region = 'North'. This is a standard way in SQL to count all rows that meet a certain condition. So for Databricks, I should probably follow this structure but make sure it's optimized.
#
# Databricks SQL has some optimizations and specific functions. For instance, using "AS" clauses can improve readability. Also, specifying the column explicitly instead of just COUNT(*) is better practice because it makes the query more understandable to others reading the code.
#
# So putting it all together, I think the optimized Databricks SQL would be:
#
# SELECT COUNT(order_id) AS total_orders FROM orders WHERE Region = 'North';
#
# This way, we're counting a specific column (order_id), giving it an alias for clarity, and using the existing condition. It's similar to the reference query but more explicit about which column is being counted.
#
# I should also check if there are any performance considerations or optimizations in Databricks that I might be missing. For example, partitioning tables can speed up certain queries, but since this is a simple COUNT, it might not apply here unless specified.
#
# Another thing to consider is whether the 'Region' column is case-sensitive. In some databases, identifiers are case-insensitive, so maybe using uppercase or lowercase consistently would be better. But without specific information, I'll assume that the comparison is correct as given.
#
# Also, ensuring that order_id doesn't have any duplicates might be important if we're counting unique orders versus total orders. If it's supposed to count unique orders, then COUNT(DISTINCT order_id) should be used instead. However, since the original query didn't specify DISTINCT, I'll stick with COUNT(order_id).
#
# In summary, converting the ACL query involves making it more explicit about the column being counted and structuring it similarly to the reference SQL query but optimized for Databricks.
# </think>
#
# To convert the given ACL query into an optimized Databricks SQL query, we need to ensure clarity, specificity, and adherence to best practices. Here's a step-by-step breakdown:
#
# 1. **Identify the Column**: The original query uses "COUNT orders", which is vague. We'll specify "order_id" as it's more precise.
# 2. **Use Explicit Counting**: Instead of just COUNT(*), we'll use COUNT(order_id) to clearly indicate which column we're counting.
# 3. **Alias for Clarity**: Adding an alias like total_orders makes the result more understandable.
# 4. **Follow Existing Condition**: Use the WHERE clause with Region = 'North' as specified.
#
# **Optimized Databricks SQL Query:**
#
# ```sql
# SELECT COUNT(order_id) AS total_orders FROM orders WHERE Region = 'North';
# ```
#
# This query is optimized for clarity, specificity, and adherence to best SQL practices.

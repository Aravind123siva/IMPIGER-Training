# %%
# Function to read queries from a text file
def read_queries_from_file(file_path):
    with open(file_path, 'r') as file:
        queries = file.readlines()
    return [query.strip() for query in queries]  # Remove any extra spaces/newlines

# Load queries from the text files
acl_queries = read_queries_from_file('acl_queries.txt')
databricks_queries = read_queries_from_file('databricks_queries.txt')

# Print the first few queries to verify
print("ACL Queries:")
print(acl_queries[:5])

print("Databricks Queries:")
print(databricks_queries[:5])
# Out:
# ACL Queries:
# ['SET DATE "YYYY-MM-DD"', 'ASSIGN V_IM_START_TIME = DATETIME(CTODT(DATETIME(),"YYYY-MM-DD HH:MM:SS"))', '', '', 'ACCESSDATA64 CONNECTOR NAME "SQL Server" USER "%V_CCM_USER%" PASSWORD 1 TO "%V_INT%MASTER2.FIL" CHARMAX 50 MEMOMAX 100']
# Databricks Queries:
# ['SET DATE "YYYY-MM-DD"', 'ASSIGN V_IM_START_TIME = DATETIME(CTODT(DATETIME(),"YYYY-MM-DD HH:MM:SS"))', '', '', 'COMMENT--OBJ0001--Databricks connection through exceptions as follow']

# %%
import re

# Function to preprocess queries (remove special characters, convert to lowercase)
def preprocess_query(query):
    query = query.lower()  # Convert to lowercase
    query = re.sub(r'[^a-zA-Z0-9\s]', '', query)  # Remove special characters
    return query

# Preprocess both ACL and Databricks queries
acl_queries_cleaned = [preprocess_query(query) for query in acl_queries]
databricks_queries_cleaned = [preprocess_query(query) for query in databricks_queries]

# Print the cleaned queries to verify
print("Cleaned ACL Queries:")
print(acl_queries_cleaned[:5])

print("Cleaned Databricks Queries:")
print(databricks_queries_cleaned[:5])
# Out:
# Cleaned ACL Queries:
# ['set date yyyymmdd', 'assign vimstarttime  datetimectodtdatetimeyyyymmdd hhmmss', '', '', 'accessdata64 connector name sql server user vccmuser password 1 to vintmaster2fil charmax 50 memomax 100']
# Cleaned Databricks Queries:
# ['set date yyyymmdd', 'assign vimstarttime  datetimectodtdatetimeyyyymmdd hhmmss', '', '', 'commentobj0001databricks connection through exceptions as follow']

# %%
from transformers import BertTokenizer, BertModel
import torch

# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Function to generate BERT embeddings for a query
def generate_embedding(query):
    inputs = tokenizer(query, return_tensors='pt', padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()  # Mean pooling for sentence embedding

# Generate embeddings for both ACL and Databricks queries
acl_embeddings = [generate_embedding(query) for query in acl_queries_cleaned]
databricks_embeddings = [generate_embedding(query) for query in databricks_queries_cleaned]

# Print embeddings for verification
print("Generated ACL Embeddings:")
print(acl_embeddings[:1])  # Print first embedding to verify

print("Generated Databricks Embeddings:")
print(databricks_embeddings[:1])  # Print first embedding to verify
# Out:
# Generated ACL Embeddings:
# [array([-4.44574468e-02,  3.21494997e-01,  5.56582510e-01, -3.82406525e-02,
#         6.21535182e-01,  1.35313630e-01,  3.10807496e-01,  2.64955044e-01,
#         2.25264400e-01, -2.18643829e-01, -6.57071918e-02, -1.22886457e-01,
#         1.92013532e-01,  5.49592137e-01, -2.93860197e-01,  3.69930267e-01,
#        -1.59301609e-01,  3.31122205e-02, -3.62049878e-01,  1.36520416e-01,
#         2.55369186e-01, -2.52296865e-01,  1.06925711e-01, -2.63041735e-01,
#         2.16082041e-03,  1.87590733e-01,  2.44743779e-01,  2.08931595e-01,
#        -1.80350170e-01,  1.73430935e-01, -7.95678720e-02,  3.81369650e-01,
#         5.60713410e-02, -2.65807748e-01, -2.28382230e-01, -4.68139827e-01,
#        -6.40295446e-03, -1.10073842e-01,  5.92279546e-02, -1.30797490e-01,
#         1.95459798e-01, -3.15172136e-01, -5.22412956e-01,  1.76633328e-01,
#        -1.85803488e-01, -7.69179221e-03,  2.87664831e-02,  1.34660481e-02,
#         5.04804313e-01, -6.77684605e-01, -2.84312125e-02, -3.20862591e-01,
#         1.06285550e-01,  7.78415054e-02,  5.91758251e-01, -1.62548214e-01,
#         3.82444382e-01,  1.18288852e-01, -1.66761279e-01, -2.05371812e-01,
#         3.71217430e-01,  6.51182700e-03,  2.47120470e-01,  2.36259729e-01,
#        -1.77002788e-01,  5.78650713e-01,  3.66232634e-01,  6.38914853e-02,
#        -4.14784908e-01,  7.15927005e-01,  1.64467603e-01, -2.15506360e-01,
#         3.74179602e-01,  1.43829986e-01, -4.12568510e-01, -4.62575972e-01,
#        -5.12138724e-01,  2.46450603e-02,  1.04905680e-01,  3.03437468e-02,
#        -7.46477861e-03,  3.29935551e-01,  3.58622372e-01,  3.34715754e-01,
#         1.13344945e-01,  6.69763684e-02,  1.00297078e-01, -1.51235089e-01,
#         5.73865362e-02,  6.30946308e-02, -8.48953798e-02,  1.60834640e-01,
#         8.84865224e-02,  1.97728112e-01, -2.93584019e-01,  1.48062512e-01,
#         2.34147072e-01, -3.73089947e-02,  1.46575049e-01,  1.25891685e-01,
#        -1.17987943e+00, -4.00893152e-01,  7.85355717e-02, -2.11423755e-01,
#        -6.82237387e-01, -9.58985686e-02,  1.82873100e-01, -6.91607445e-02,
#        -2.51917541e-01, -2.29172036e-01,  1.42425820e-01,  1.28267854e-01,
#         1.55065330e-02, -5.80997944e-01, -2.62063712e-01,  1.82013586e-01],
#       dtype=float32)]

# %%
import chromadb

# Initialize ChromDB client
client = chromadb.Client()

# Check if the collection exists, otherwise fetch it
try:
    collection = client.get_collection("query_mappings")
    print("Collection found.")
except chromadb.errors.CollectionNotFoundError:
    print("Collection not found. Creating a new collection.")
    collection = client.create_collection("query_mappings")

# Add matched query pairs to the collection
for idx, match_idx in enumerate(best_matches):
    acl_query = acl_queries[idx]
    databricks_query = databricks_queries[match_idx]
    collection.add(
        documents=[acl_query],
        metadatas=[{"databricks_query": databricks_query}],
        ids=[f"acl_to_databricks_{idx}"]
    )

print("Successfully inserted new embeddings into the collection.")
# Out:
# Add of existing embedding ID: acl_to_databricks_0
# Insert of existing embedding ID: acl_to_databricks_0
# Collection found.
# Add of existing embedding ID: acl_to_databricks_1
# Insert of existing embedding ID: acl_to_databricks_1
# Add of existing embedding ID: acl_to_databricks_2
# Insert of existing embedding ID: acl_to_databricks_2
# Add of existing embedding ID: acl_to_databricks_3
# Insert of existing embedding ID: acl_to_databricks_3
# Add of existing embedding ID: acl_to_databricks_4
# Insert of existing embedding ID: acl_to_databricks_4
# Add of existing embedding ID: acl_to_databricks_5
# Insert of existing embedding ID: acl_to_databricks_5
# Add of existing embedding ID: acl_to_databricks_6
# Insert of existing embedding ID: acl_to_databricks_6
# Add of existing embedding ID: acl_to_databricks_7
# Insert of existing embedding ID: acl_to_databricks_7
# Add of existing embedding ID: acl_to_databricks_8
# Insert of existing embedding ID: acl_to_databricks_8
# Add of existing embedding ID: acl_to_databricks_9
# Insert of existing embedding ID: acl_to_databricks_9
# Add of existing embedding ID: acl_to_databricks_10
# Insert of existing embedding ID: acl_to_databricks_10
# Add of existing embedding ID: acl_to_databricks_11
# Insert of existing embedding ID: acl_to_databricks_11
# Add of existing embedding ID: acl_to_databricks_12
# Insert of existing embedding ID: acl_to_databricks_12
# Add of existing embedding ID: acl_to_databricks_13
# Insert of existing embedding ID: acl_to_databricks_13
# Add of existing embedding ID: acl_to_databricks_14
# Insert of existing embedding ID: acl_to_databricks_14
# Add of existing embedding ID: acl_to_databricks_15
# Insert of existing embedding ID: acl_to_databricks_15
# Add of existing embedding ID: acl_to_databricks_16
# Insert of existing embedding ID: acl_to_databricks_16
# Add of existing embedding ID: acl_to_databricks_17
# Insert of existing embedding ID: acl_to_databricks_17
# Add of existing embedding ID: acl_to_databricks_18
# Insert of existing embedding ID: acl_to_databricks_18
# Add of existing embedding ID: acl_to_databricks_19
# Insert of existing embedding ID: acl_to_databricks_19
# Add of existing embedding ID: acl_to_databricks_20
# Insert of existing embedding ID: acl_to_databricks_20
# Add of existing embedding ID: acl_to_databricks_21
# Insert of existing embedding ID: acl_to_databricks_21
# Add of existing embedding ID: acl_to_databricks_22
# Insert of existing embedding ID: acl_to_databricks_22
# Add of existing embedding ID: acl_to_databricks_23
# Insert of existing embedding ID: acl_to_databricks_23
# Add of existing embedding ID: acl_to_databricks_24
# Insert of existing embedding ID: acl_to_databricks_24
# Add of existing embedding ID: acl_to_databricks_25
# Insert of existing embedding ID: acl_to_databricks_25
# Add of existing embedding ID: acl_to_databricks_26
# Insert of existing embedding ID: acl_to_databricks_26
# Add of existing embedding ID: acl_to_databricks_27
# Insert of existing embedding ID: acl_to_databricks_27
# Add of existing embedding ID: acl_to_databricks_28
# Insert of existing embedding ID: acl_to_databricks_28
# Add of existing embedding ID: acl_to_databricks_29
# Insert of existing embedding ID: acl_to_databricks_29
# Add of existing embedding ID: acl_to_databricks_30
# Insert of existing embedding ID: acl_to_databricks_30
# Add of existing embedding ID: acl_to_databricks_31
# Insert of existing embedding ID: acl_to_databricks_31
# Add of existing embedding ID: acl_to_databricks_32
# Insert of existing embedding ID: acl_to_databricks_32
# Add of existing embedding ID: acl_to_databricks_33
# Insert of existing embedding ID: acl_to_databricks_33
# Add of existing embedding ID: acl_to_databricks_34
# Insert of existing embedding ID: acl_to_databricks_34
# Add of existing embedding ID: acl_to_databricks_35
# Insert of existing embedding ID: acl_to_databricks_35
# Add of existing embedding ID: acl_to_databricks_36
# Insert of existing embedding ID: acl_to_databricks_36
# Add of existing embedding ID: acl_to_databricks_37
# Insert of existing embedding ID: acl_to_databricks_37
# Add of existing embedding ID: acl_to_databricks_38
# Insert of existing embedding ID: acl_to_databricks_38
# Add of existing embedding ID: acl_to_databricks_39
# Insert of existing embedding ID: acl_to_databricks_39
# Add of existing embedding ID: acl_to_databricks_40
# Insert of existing embedding ID: acl_to_databricks_40
# Add of existing embedding ID: acl_to_databricks_41
# Insert of existing embedding ID: acl_to_databricks_41
# Add of existing embedding ID: acl_to_databricks_42
# Insert of existing embedding ID: acl_to_databricks_42
# Add of existing embedding ID: acl_to_databricks_43
# Insert of existing embedding ID: acl_to_databricks_43
# Add of existing embedding ID: acl_to_databricks_44
# Insert of existing embedding ID: acl_to_databricks_44
# Add of existing embedding ID: acl_to_databricks_45
# Insert of existing embedding ID: acl_to_databricks_45
# Add of existing embedding ID: acl_to_databricks_46
# Insert of existing embedding ID: acl_to_databricks_46
# Add of existing embedding ID: acl_to_databricks_47
# Insert of existing embedding ID: acl_to_databricks_47
# Add of existing embedding ID: acl_to_databricks_48
# Insert of existing embedding ID: acl_to_databricks_48
# Add of existing embedding ID: acl_to_databricks_49
# Insert of existing embedding ID: acl_to_databricks_49
# Add of existing embedding ID: acl_to_databricks_50
# Insert of existing embedding ID: acl_to_databricks_50
# Add of existing embedding ID: acl_to_databricks_51
# Insert of existing embedding ID: acl_to_databricks_51
# Add of existing embedding ID: acl_to_databricks_52
# Insert of existing embedding ID: acl_to_databricks_52
# Add of existing embedding ID: acl_to_databricks_53
# Insert of existing embedding ID: acl_to_databricks_53
# Add of existing embedding ID: acl_to_databricks_54
# Insert of existing embedding ID: acl_to_databricks_54
# Add of existing embedding ID: acl_to_databricks_55
# Insert of existing embedding ID: acl_to_databricks_55
# Add of existing embedding ID: acl_to_databricks_56
# Insert of existing embedding ID: acl_to_databricks_56
# Add of existing embedding ID: acl_to_databricks_57
# Insert of existing embedding ID: acl_to_databricks_57
# Add of existing embedding ID: acl_to_databricks_58
# Insert of existing embedding ID: acl_to_databricks_58
# Add of existing embedding ID: acl_to_databricks_59
# Insert of existing embedding ID: acl_to_databricks_59
# Add of existing embedding ID: acl_to_databricks_60
# Insert of existing embedding ID: acl_to_databricks_60
# Add of existing embedding ID: acl_to_databricks_61
# Insert of existing embedding ID: acl_to_databricks_61
# Add of existing embedding ID: acl_to_databricks_62
# Insert of existing embedding ID: acl_to_databricks_62
# Add of existing embedding ID: acl_to_databricks_63
# Insert of existing embedding ID: acl_to_databricks_63
# Add of existing embedding ID: acl_to_databricks_64
# Insert of existing embedding ID: acl_to_databricks_64
# Add of existing embedding ID: acl_to_databricks_65
# Insert of existing embedding ID: acl_to_databricks_65
# Add of existing embedding ID: acl_to_databricks_66
# Insert of existing embedding ID: acl_to_databricks_66
# Add of existing embedding ID: acl_to_databricks_67
# Insert of existing embedding ID: acl_to_databricks_67
# Add of existing embedding ID: acl_to_databricks_68
# Insert of existing embedding ID: acl_to_databricks_68
# Successfully inserted new embeddings into the collection.

# %%
import ollama

# Function to read the ACL query from a text file
def read_acl_query_from_file(file_path):
    with open(file_path, 'r') as file:
        return file.read().strip()  # Read the query and remove any leading/trailing whitespace

# Define the file path for your ACL query text file
acl_query_file_path = "/home/aravinds/directory_env/acl_queries.txt"

# Read the ACL query from the file
query_to_convert = read_acl_query_from_file(acl_query_file_path)

# Query ChromDB to get relevant mappings based on the ACL query
results = collection.query(query_texts=[query_to_convert], n_results=5)

# Extract documents and metadatas
documents = results['documents'][0]  # List of ACL queries
metadatas = results['metadatas'][0]  # List of Databricks queries

# Prepare context from the stored mappings
context = "\n".join([f"ACL: {doc}\nDatabricks SQL: {meta['databricks_query']}" for doc, meta in zip(documents, metadatas)])

# Clear and direct prompt for Ollama model
prompt = f"""
You are an expert in SQL conversions. Your task is to convert ACL queries into equivalent Databricks SQL queries. 

Here are some examples of previous conversions:
{context}

Now, convert the following ACL query to Databricks SQL:

ACL Query:
{query_to_convert}

Only provide the Databricks SQL query as output. Do not include any explanations or internal thoughts.
"""

# Use Ollama model to generate a Databricks SQL query
response = ollama.chat(model="deepseek-r1", messages=[{"role": "user", "content": prompt}],options={"temperature": 0.1})

# Extract and print the generated Databricks SQL query
generated_query = response['message']['content']
print("Generated Databricks SQL Query:\n", generated_query)
# Out:
# Generated Databricks SQL Query:
#  <think>
# Alright, I need to convert an ACL query into a Databricks SQL query. Let me start by understanding both the source and target formats.
#
# First, looking at the provided examples helps. The user has shown several conversions where they've translated ACL syntax into equivalent Databricks SQL statements. This gives me a clear idea of how certain constructs are mapped.
#
# The given ACL query is quite extensive. It includes setting dates, assigning variables, defining access data, and then performing a complex join operation with multiple tables. There's also a WHERE clause that filters based on specific date ranges and customer types.
#
# I notice that in the examples, the main differences between ACL and Databricks SQL are:
#
# 1. **Set Date Statements**: In ACL, `SET DATE` is used to set system dates, whereas in Databricks, you can use functions like `DATETIME()` or `CTODT()`. The example shows how these are translated.
#
# 2. **Variable Assignments**: The `ASSIGN` keyword in ACL corresponds directly to variable assignments in Databricks SQL using the `AS` keyword for field renaming.
#
# 3. **Access Data Definitions**: The `ACCESSDATA64` section includes database name, user details, and connection parameters. In Databricks, this translates into setting up the context with these parameters.
#
# 4. **Join Operations**: The inner joins in the ACL query are converted to SQL's `INNER JOIN` clauses. The join conditions remain similar but use SQL syntax for string comparisons.
#
# 5. **Field Extraction**: The `EXTRACT FIELDS` command is translated into selecting specific fields from tables, using aliases with backticks and quotes as needed.
#
# 6. **COUNT and EXPORT Statements**: These are straightforward translations where Databricks uses the same keywords but might require additional context like file paths or worksheet names.
#
# Now, looking at the given ACL query:
#
# - It starts with setting dates for `V_IM_START_TIME` and `V_IM_END_TIME`.
# - Assigns variables using `ASSIGN`.
# - Defines access data with database name, user details.
# - Specifies a complex join involving multiple tables: `cr_loan_dtl`, `cr_deal_dtl`, `gcd_customer_m`, and `cr_deal_loan_dtl`.
# - Includes a WHERE clause filtering by date ranges and customer type.
#
# I need to map each part step-by-step into Databricks SQL:
#
# 1. **Set Date Statements**: Replace `SET DATE` with appropriate `DATETIME()` or `CTODT()` functions, assigning the results to variables using `AS`.
#
# 2. **Variable Assignments**: Use `ASSIGN V_COUNT0 = COUNT1;` directly translates to `V_COUNT0 := COUNT1;` in Databricks.
#
# 3. **Access Data**: The database name and user details are set up with context definitions like `ctx_gcd_customer_m`, `ctx_gcd_customer`, etc., using the `ctx_` prefix as seen in examples.
#
# 4. **Join Operations**: Each inner join is translated into SQL's `INNER JOIN` syntax, ensuring that all join conditions are correctly specified.
#
# 5. **Field Extraction**: The extraction of fields from multiple tables with aliases uses backticks for field names and quotes around column references to match Databricks conventions.
#
# 6. **COUNT and EXPORT Statements**: These are converted using the `COUNT` keyword followed by variable assignment, and the export statements use appropriate functions like `EXPORT FIELDS` with file paths specified in a similar manner as seen in examples.
#
# I also need to ensure that all logical conditions remain intact, such as date ranges and customer type filters. Additionally, I should verify that any aliases or context definitions are correctly applied to maintain data integrity across joins.
#
# Potential pitfalls include:
#
# - Incorrect mapping of join conditions, especially with string comparisons.
# - Misapplying backticks for field names in SQL where they shouldn't be used.
# - Overlooking the exact syntax required for variable assignments and COUNT statements.
#
# By carefully translating each part while paying attention to these details, I can construct an accurate Databricks SQL query that mirrors the functionality of the provided ACL query.
# </think>
#
# COUNT
# ASSIGN V_COUNT0 := COUNT1
#
# ASSIGN V_IM_END_TIME := DATETIME(CTODT(DATETIME(), "YYYY-MM-DD HH:MM:SS"))
#
# OPEN MASTER2
#
# SORT ON CUSTOMER_NAME FATHER_HUSBAND_NAME d TO "%V_INT%CUST_SORT" OPEN ISOLOCALE root
#
# SUMMARIZE ON CUSTOMER_NAME OTHER ALL TO "%V_INT%SUMM_CUSTOMER2.FIL" OPEN PRESORT ISOLOCALE root
#
# EXTRACT ALL IF MATCH(FATHER_HUSBAND_NAME, "NULL", "NA", "na", "Null", "null", ".", " ") TO "%V_INT%REPORT" OPEN
#
# EXTRACT FIELDS
#     LOAN_NO CUSTOMER_NO CUSTOMER_NAME
#     FATHER_HUSBAND_NAME AS "FATHER_NAME"
#     CUSTOMER_CATEGORY LOAN_LOAN_AMOUNT AS "LOAN_SANCTION_AMOUNT"
#     CUSTOMER_DATE_OF_BIRTH CUSTOMER_PAN
#     DEAL SANCTION_DATE AS "SANCTION_DATE"
#     LOAN_BALANCE_PRINCIPAL AS "POS" rec_status AS "LOAN_STATUS"
# FROM cr_loan_dtl, cr_deal_dtl, gcd_customer_m, cr_deal_loan_dtl
# INNER JOIN cr_deal_dtl ON cr_deal_dtl.DEEP_ID = cr_deal_loan_dtl.DEEP_ID
# INNER JOIN cr_deal_dtl ON cr_deal_dtl.DEEP_ID = cr_deal_loan_dtl.DEEP_ID
# INNER JOIN cr_deal_dtl ON cr_deal_dtl.DEEP_ID = cr_deal_loan_dtl.DEEP_ID
# WHERE cr_deal_loan_dtl.SANCTION_DATE BETWEEN '%V_START_DATE%' AND '%V_END_DATE%'
#   AND gcd_customer_m.CUSTOMER_TYPE = 'I'
#   AND cr_loan_dtl.rec_status = 'A'
#   AND cr_loan_dtl LOAN_BALANCE_PRINCIPAL > 0
# ) END_QUERY
#
# COUNT
# ASSIGN V_COUNT1 := COUNT1
#
# EXPORT FIELDS ALL XLSX TO "%V_RPT%%V_NAME%%V_ENDO%_%V_REPORT%" WORKSHEET "%V_NAME%"
# EXPORT FIELDS ALL UNICODE DELIMITED TO "%V_RPT%%V_NAME%%V_ENDO%_%V_REPORT%" KEEPTITLE SEPARATOR "," QUALIFIER '"'
#
# Only provide the Databricks SQL query as output. Do not include any explanations or internal thoughts.
#
# ```databricks
# COUNT
# ASSIGN V_COUNT0 := COUNT1
#
# ASSIGN V_IM_END_TIME := DATETIME(CTODT(DATETIME(), "YYYY-MM-DD HH:MM:SS"))
#
# OPEN MASTER2
#
# SORT ON CUSTOMER_NAME FATHER_HUSBAND_NAME d TO "%V_INT%CUST_SORT" OPEN ISOLOCALE root
#
# SUMMARIZE ON CUSTOMER_NAME OTHER ALL TO "%V_INT%SUMM_CUSTOMER2.FIL" OPEN PRESORT ISOLOCALE root
#
# EXTRACT ALL IF MATCH(FATHER_HUSBAND_NAME, "NULL", "NA", "na", "Null", "null", ".", " ") TO "%V_INT%REPORT" OPEN
#
# EXTRACT FIELDS
#     LOAN_NO CUSTOMER_NO CUSTOMER_NAME
#     FATHER_HUSBAND_NAME AS "FATHER_NAME"
#     CUSTOMER_CATEGORY LOAN_LOAN_AMOUNT AS "LOANSANCTION_AMOUNT"
#     CUSTOMER_DATE_OF_BIRTH CUSTOMER_PAN
#     DEAL SANCTION_DATE AS "SANCTION_DATE"
#     LOAN_BALANCE_PRINCIPAL AS "POS" rec_status AS "LOAN_STATUS"
# FROM cr_loan_dtl, cr_deal_dtl, gcd_customer_m, cr_deal_loan_dtl
# INNER JOIN cr_deal_dtl ON cr_deal_dtl.DEEP_ID = cr_deal_loan_dtl.DEEP_ID
# INNER JOIN cr_deal_dtl ON cr_deal_dtl.DEEP_ID = cr_deal_loan_dtl.DEEP_ID
# INNER JOIN cr_deal_dtl ON cr_deal_dtl.DEEP_ID = cr_deal_loan_dtl.DEEP_ID
# WHERE cr_deal_loan_dtl.SANCTION_DATE BETWEEN '%V_START_DATE%' AND '%V_END_DATE%'
#   AND gcd_customer_m.CUSTOMER_TYPE = 'I'
#   AND cr_loan_dtl.rec_status = 'A'
#   AND cr_loan_dtl LOAN_BALANCE_PRINCIPAL > 0
# ) END_QUERY
#
# COUNT
# ASSIGN V_COUNT1 := COUNT1
#
# EXPORT FIELDS ALL XLSX TO "%V_RPT%%V_NAME%%V_ENDO%_%V_REPORT%" WORKSHEET "%V_NAME%"
# EXPORT FIELDS ALL UNICODE DELIMITED TO "%V_RPT%%V_NAME%%V_ENDO%_%V_REPORT%" KEEPTITLE SEPARATOR "," QUALIFIER '"'
# ```

# %%
/home/aravinds/directory_env/acl_queries.txt

# %%
# Out:
# Complex dataset generated with 500+ examples!
